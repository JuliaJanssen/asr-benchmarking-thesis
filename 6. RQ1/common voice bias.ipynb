# %%
import os
import subprocess
from pathlib import Path
from collections import defaultdict
import pandas as pd

# %%
hyp_path = Path("path/to/your/data/analysis/hyp") ###
ref_path = Path("path/to/your/data/analysis/ref") ###
out_path = Path("path/to/your/data/analysis/results/1. bias") ###

# %%
def extract_speaker_metadata(models_root: Path, stm_path: Path) -> dict:
    """
    Extracts speaker metadata from .sys (SCTK) and .stm (reference transcript) files and returns a pandas DataFrame.

    Args:
        models_root (Path): Path to folder containing model subfolders with .sys files.
        stm_path (Path): Path to folder containing reference .stm files.

    Returns: 
        pd.DataFrame: Rows with columns ['sys_filename', 'speaker_id', 'gender', 'age_bin']
    """
    speaker_metadata = defaultdict(dict)

    for model_dir in models_root.iterdir():
        if not model_dir.is_dir():
            continue

        for subset_dir in model_dir.iterdir():
            if not subset_dir.is_dir():
                continue
            #set 0 for common voice
            if not any(digit in subset_dir.stem.split('_')[1] for digit in ['0']):
                continue
            print(f"Processing subset directory: {subset_dir.name}")

            for sys_file in subset_dir.glob("*.ctm.sys"):
                speaker_ids = []

                #extract speaker ids from .sys file
                with sys_file.open("r", encoding="utf-8") as f:
                    for line in f:
                        if line.startswith("|") and "|" in line[1:]:
                            columns = line.strip().split("|")
                            if len(columns) > 1:
                                candidate = columns[1].strip()
                                if candidate and candidate.startswith(("spk")):
                                    speaker_ids.append(candidate)
                print(f"Found {len(speaker_ids)} speakers in {sys_file.name}")
                print(f"Speaker IDs: {speaker_ids}")

                stm_file = stm_path / f"{0}_reference.stm"

                #extract metadata strings per speaker from .stm file
                with stm_file.open("r", encoding="utf-8") as f:
                    for line in f:
                        parts = line.strip().split()
                        if len(parts) < 6:
                            continue
                        speaker = parts[2]
                        meta_start = line.find('<')
                        meta_end = line.find('>', meta_start)
                        if meta_start != -1 and meta_end != -1 and speaker.lower() in speaker_ids:
                            metadata = line[meta_start + 1:meta_end]
                            speaker_metadata[sys_file.name][speaker] = metadata

    #parse metadata strings into structured data
    rows = []
    for sys_filename, speakers_meta in speaker_metadata.items():
        for spk, meta_str in speakers_meta.items():
            try:
                parts = meta_str.split(",")
                age_bin, gender = parts[0], parts[1] 
            except Exception as e:
                print(f"Error parsing metadata '{meta_str}' for speaker '{spk}' in '{sys_filename}': {e}")
                continue

            rows.append({
                "sys_filename": sys_filename,
                "speaker_id": spk,
                "gender": gender,
                "age_bin": age_bin,
            })

    return pd.DataFrame(rows)

# %%
def extract_speaker_performance(models_root: Path) -> dict:
    #extracts number of words and WER per speaker from each .sys file in model folders

    speaker_performance = defaultdict(dict)

    for model_dir in models_root.iterdir():
        if not model_dir.is_dir():
            continue

        for subset_dir in model_dir.iterdir():
            if not subset_dir.is_dir():
                continue
            #0 for common voice
            if not any(digit in subset_dir.stem.split('_')[1] for digit in ['0']):
                continue

            for sys_file in subset_dir.glob("*.ctm.sys"):
                current_sys = sys_file.name

                with sys_file.open("r", encoding="utf-8") as f:
                    for line in f:
                        #skip header, footer, or empty lines
                        if not line.startswith("|") or "---" in line or line.count("|") < 3:
                            continue

                        parts = [p.strip() for p in line.strip().strip("|").split("|")]
                        if len(parts) < 3:
                            continue

                        speaker_id = parts[0]
                        if not (speaker_id.lower().startswith("spk")):
                            continue

                        try:
                            word_stats = parts[1].split()
                            err_stats = parts[2].split()

                            num_words = int(word_stats[1])  # #wrd is second in word_stats
                            wer = float(err_stats[4])       # err is fifth in err_stats

                            speaker_performance[current_sys][speaker_id] = {
                                "num_words": num_words,
                                "wer": wer
                            }
                        except (ValueError, IndexError):
                            continue

    return speaker_performance

# %%
metadata = extract_speaker_metadata(out_path, ref_path)
speaker_performance = extract_speaker_performance(out_path)

#quick check
#print(metadata.head())
#print(speaker_performance)

#detailed examples
#for sysfile, spk_data in metadata.items():
#    print(f"{sysfile}:")
#    for spk, meta in spk_data.items():
#        print(f"  {spk}: {meta}")

# %%
def highlight_extremes(dataframe):
    styles = pd.DataFrame('background-color: white; color: black', index=dataframe.index, columns=dataframe.columns)

    avg_row_mask = dataframe.index.get_level_values("Age Bin") == "Avg"
    avg_cols = [col for col in dataframe.columns if col.endswith("_Avg")]

    #gray out avg rows and columns
    styles.loc[avg_row_mask] = 'background-color: #dddddd; color: black; font-weight: bold'
    for col in avg_cols:
        styles[col] = 'background-color: #dddddd; color: black; font-weight: bold'

    #column-wise min/max highlighting (excluding avg rows)
    for col in dataframe.columns:
        if col in avg_cols:
            continue

        col_values = dataframe.loc[~avg_row_mask, col]
        min_val = col_values.min(skipna=True)
        max_val = col_values.max(skipna=True)

        for idx in dataframe.index:
            if pd.isna(dataframe.at[idx, col]) or avg_row_mask[dataframe.index.get_loc(idx)]:
                continue
            if dataframe.at[idx, col] == min_val:
                styles.at[idx, col] = 'background-color: #cce5cc; color: black'
            elif dataframe.at[idx, col] == max_val:
                styles.at[idx, col] = 'background-color: #f5cccc; color: black'

    return styles

# %%
genders = ["female", "male"]
age_bins = ["teens", "twenties", "thirties", "fourties", "fifties", "sixties+"]

def get_wer_by_demographic(speaker_info, speaker_performance):
    #structure: [age_bin][gender] -> {'wer_sum': ..., 'words_sum': ...}
    data = defaultdict(lambda: defaultdict(lambda: {'wer_sum': 0.0, 'words_sum': 0}))
    nr_dropped = 0

    for _, row in speaker_info.iterrows():
        speaker_id = row['speaker_id'].strip().lower()
        perf = speaker_performance.get(speaker_id)
        if perf is None:
            nr_dropped += 1
            print(f"No performance data for speaker {speaker_id}")
            continue

        wer = perf['wer']
        num_words = perf['num_words']

        age_bin = row['age_bin']
        gender = row['gender']

        #map sixties/seventies/eighties to sixties+
        if age_bin in ["sixties", "seventies", "eighties"]:
            age_bin = "sixties+"

        if age_bin not in age_bins or gender not in genders:
            nr_dropped += 1
            print(f"Invalid demographic data for speaker {speaker_id}: age_bin={age_bin}, gender={gender}")
            continue

        entry = data[age_bin][gender]
        entry['wer_sum'] += wer * num_words
        entry['words_sum'] += num_words

    rows = []
    for age_bin in age_bins:
        row = {}
        for gender in genders:
            cell = data[age_bin][gender]
            wer_value = cell['wer_sum'] / cell['words_sum'] if cell['words_sum'] > 0 else None
            row[gender] = wer_value
        #average across genders for this age bin
        total_words = sum(data[age_bin][g]['words_sum'] for g in genders)
        total_wer = sum(data[age_bin][g]['wer_sum'] for g in genders)
        row['Avg'] = total_wer / total_words if total_words > 0 else None
        row['Age Bin'] = age_bin
        rows.append(row)

    df = pd.DataFrame(rows)
    df = df.set_index('Age Bin')
    df = df[genders + ['Avg']]

    df = df.round(1)
    
    styled_df = df.style.apply(highlight_extremes, axis=None).format("{:.1f}")
    display(styled_df)

# %%
for subfolder in os.listdir(out_path):
    sub_metadata = metadata[(metadata.iloc[:, 0].str.split("_").str[0] == subfolder)]
    sub_speaker_performance = {}
    
    for subset in range(0,1):
        key = f"{subfolder}_{subset}_filtered.ctm.sys"
        perf_dict = speaker_performance.get(key)

        if perf_dict is None:
            print(f"Missing performance data for: {key}")
        else:
            sub_speaker_performance.update(perf_dict)

    print(f"Analyzing subset: {subfolder}")
    get_wer_by_demographic(sub_metadata, sub_speaker_performance)
# Out:
# Analyzing subset: aws-transcribe
# <style type="text/css">
# #T_c0edb_row0_col0, #T_c0edb_row1_col1, #T_c0edb_row1_col2, #T_c0edb_row2_col0, #T_c0edb_row2_col1, #T_c0edb_row2_col2, #T_c0edb_row3_col1, #T_c0edb_row3_col2, #T_c0edb_row4_col0, #T_c0edb_row4_col1, #T_c0edb_row4_col2, #T_c0edb_row5_col0 {
#   background-color: white;
#   color: black;
# }
# #T_c0edb_row0_col1, #T_c0edb_row0_col2, #T_c0edb_row1_col0 {
#   background-color: #f5cccc;
#   color: black;
# }
# #T_c0edb_row3_col0, #T_c0edb_row5_col1, #T_c0edb_row5_col2 {
#   background-color: #cce5cc;
#   color: black;
# }
# </style>
# <table id="T_c0edb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0edb_level0_col0" class="col_heading level0 col0" >female</th>
#       <th id="T_c0edb_level0_col1" class="col_heading level0 col1" >male</th>
#       <th id="T_c0edb_level0_col2" class="col_heading level0 col2" >Avg</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0edb_level0_row0" class="row_heading level0 row0" >teens</th>
#       <td id="T_c0edb_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_c0edb_row0_col1" class="data row0 col1" >1.9</td>
#       <td id="T_c0edb_row0_col2" class="data row0 col2" >1.8</td>
#     </tr>
#     <tr>
#       <th id="T_c0edb_level0_row1" class="row_heading level0 row1" >twenties</th>
#       <td id="T_c0edb_row1_col0" class="data row1 col0" >1.7</td>
#       <td id="T_c0edb_row1_col1" class="data row1 col1" >1.5</td>
#       <td id="T_c0edb_row1_col2" class="data row1 col2" >1.6</td>
#     </tr>
#     <tr>
#       <th id="T_c0edb_level0_row2" class="row_heading level0 row2" >thirties</th>
#       <td id="T_c0edb_row2_col0" class="data row2 col0" >1.6</td>
#       <td id="T_c0edb_row2_col1" class="data row2 col1" >1.7</td>
#       <td id="T_c0edb_row2_col2" class="data row2 col2" >1.7</td>
#     </tr>
#     <tr>
#       <th id="T_c0edb_level0_row3" class="row_heading level0 row3" >fourties</th>
#       <td id="T_c0edb_row3_col0" class="data row3 col0" >0.9</td>
#       <td id="T_c0edb_row3_col1" class="data row3 col1" >1.6</td>
#       <td id="T_c0edb_row3_col2" class="data row3 col2" >1.3</td>
#     </tr>
#     <tr>
#       <th id="T_c0edb_level0_row4" class="row_heading level0 row4" >fifties</th>
#       <td id="T_c0edb_row4_col0" class="data row4 col0" >1.3</td>
#       <td id="T_c0edb_row4_col1" class="data row4 col1" >1.2</td>
#       <td id="T_c0edb_row4_col2" class="data row4 col2" >1.3</td>
#     </tr>
#     <tr>
#       <th id="T_c0edb_level0_row5" class="row_heading level0 row5" >sixties+</th>
#       <td id="T_c0edb_row5_col0" class="data row5 col0" >1.3</td>
#       <td id="T_c0edb_row5_col1" class="data row5 col1" >1.0</td>
#       <td id="T_c0edb_row5_col2" class="data row5 col2" >1.1</td>
#     </tr>
#   </tbody>
# </table>
# Analyzing subset: wav2vec2-dutch-large-ft-cgn
# <style type="text/css">
# #T_fef48_row0_col0, #T_fef48_row1_col0, #T_fef48_row1_col1, #T_fef48_row1_col2, #T_fef48_row2_col1, #T_fef48_row2_col2, #T_fef48_row3_col0, #T_fef48_row3_col1, #T_fef48_row3_col2, #T_fef48_row4_col0, #T_fef48_row4_col1, #T_fef48_row4_col2 {
#   background-color: white;
#   color: black;
# }
# #T_fef48_row0_col1, #T_fef48_row0_col2, #T_fef48_row2_col0 {
#   background-color: #f5cccc;
#   color: black;
# }
# #T_fef48_row5_col0, #T_fef48_row5_col1, #T_fef48_row5_col2 {
#   background-color: #cce5cc;
#   color: black;
# }
# </style>
# <table id="T_fef48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fef48_level0_col0" class="col_heading level0 col0" >female</th>
#       <th id="T_fef48_level0_col1" class="col_heading level0 col1" >male</th>
#       <th id="T_fef48_level0_col2" class="col_heading level0 col2" >Avg</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fef48_level0_row0" class="row_heading level0 row0" >teens</th>
#       <td id="T_fef48_row0_col0" class="data row0 col0" >11.3</td>
#       <td id="T_fef48_row0_col1" class="data row0 col1" >12.6</td>
#       <td id="T_fef48_row0_col2" class="data row0 col2" >12.5</td>
#     </tr>
#     <tr>
#       <th id="T_fef48_level0_row1" class="row_heading level0 row1" >twenties</th>
#       <td id="T_fef48_row1_col0" class="data row1 col0" >12.8</td>
#       <td id="T_fef48_row1_col1" class="data row1 col1" >9.1</td>
#       <td id="T_fef48_row1_col2" class="data row1 col2" >10.9</td>
#     </tr>
#     <tr>
#       <th id="T_fef48_level0_row2" class="row_heading level0 row2" >thirties</th>
#       <td id="T_fef48_row2_col0" class="data row2 col0" >12.9</td>
#       <td id="T_fef48_row2_col1" class="data row2 col1" >9.9</td>
#       <td id="T_fef48_row2_col2" class="data row2 col2" >11.4</td>
#     </tr>
#     <tr>
#       <th id="T_fef48_level0_row3" class="row_heading level0 row3" >fourties</th>
#       <td id="T_fef48_row3_col0" class="data row3 col0" >5.8</td>
#       <td id="T_fef48_row3_col1" class="data row3 col1" >7.9</td>
#       <td id="T_fef48_row3_col2" class="data row3 col2" >6.9</td>
#     </tr>
#     <tr>
#       <th id="T_fef48_level0_row4" class="row_heading level0 row4" >fifties</th>
#       <td id="T_fef48_row4_col0" class="data row4 col0" >9.5</td>
#       <td id="T_fef48_row4_col1" class="data row4 col1" >7.8</td>
#       <td id="T_fef48_row4_col2" class="data row4 col2" >8.6</td>
#     </tr>
#     <tr>
#       <th id="T_fef48_level0_row5" class="row_heading level0 row5" >sixties+</th>
#       <td id="T_fef48_row5_col0" class="data row5 col0" >5.7</td>
#       <td id="T_fef48_row5_col1" class="data row5 col1" >4.8</td>
#       <td id="T_fef48_row5_col2" class="data row5 col2" >5.0</td>
#     </tr>
#   </tbody>
# </table>
# Analyzing subset: wav2vec2-large-xlsr-53-dutch
# <style type="text/css">
# #T_e9bb0_row0_col0, #T_e9bb0_row1_col1, #T_e9bb0_row1_col2, #T_e9bb0_row2_col0, #T_e9bb0_row2_col1, #T_e9bb0_row2_col2, #T_e9bb0_row3_col1, #T_e9bb0_row4_col0, #T_e9bb0_row4_col1, #T_e9bb0_row4_col2, #T_e9bb0_row5_col0 {
#   background-color: white;
#   color: black;
# }
# #T_e9bb0_row0_col1, #T_e9bb0_row0_col2, #T_e9bb0_row1_col0 {
#   background-color: #f5cccc;
#   color: black;
# }
# #T_e9bb0_row3_col0, #T_e9bb0_row3_col2, #T_e9bb0_row5_col1, #T_e9bb0_row5_col2 {
#   background-color: #cce5cc;
#   color: black;
# }
# </style>
# <table id="T_e9bb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9bb0_level0_col0" class="col_heading level0 col0" >female</th>
#       <th id="T_e9bb0_level0_col1" class="col_heading level0 col1" >male</th>
#       <th id="T_e9bb0_level0_col2" class="col_heading level0 col2" >Avg</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9bb0_level0_row0" class="row_heading level0 row0" >teens</th>
#       <td id="T_e9bb0_row0_col0" class="data row0 col0" >12.7</td>
#       <td id="T_e9bb0_row0_col1" class="data row0 col1" >12.3</td>
#       <td id="T_e9bb0_row0_col2" class="data row0 col2" >12.3</td>
#     </tr>
#     <tr>
#       <th id="T_e9bb0_level0_row1" class="row_heading level0 row1" >twenties</th>
#       <td id="T_e9bb0_row1_col0" class="data row1 col0" >13.1</td>
#       <td id="T_e9bb0_row1_col1" class="data row1 col1" >7.4</td>
#       <td id="T_e9bb0_row1_col2" class="data row1 col2" >10.3</td>
#     </tr>
#     <tr>
#       <th id="T_e9bb0_level0_row2" class="row_heading level0 row2" >thirties</th>
#       <td id="T_e9bb0_row2_col0" class="data row2 col0" >12.0</td>
#       <td id="T_e9bb0_row2_col1" class="data row2 col1" >9.3</td>
#       <td id="T_e9bb0_row2_col2" class="data row2 col2" >10.6</td>
#     </tr>
#     <tr>
#       <th id="T_e9bb0_level0_row3" class="row_heading level0 row3" >fourties</th>
#       <td id="T_e9bb0_row3_col0" class="data row3 col0" >3.8</td>
#       <td id="T_e9bb0_row3_col1" class="data row3 col1" >7.3</td>
#       <td id="T_e9bb0_row3_col2" class="data row3 col2" >5.6</td>
#     </tr>
#     <tr>
#       <th id="T_e9bb0_level0_row4" class="row_heading level0 row4" >fifties</th>
#       <td id="T_e9bb0_row4_col0" class="data row4 col0" >8.7</td>
#       <td id="T_e9bb0_row4_col1" class="data row4 col1" >8.6</td>
#       <td id="T_e9bb0_row4_col2" class="data row4 col2" >8.7</td>
#     </tr>
#     <tr>
#       <th id="T_e9bb0_level0_row5" class="row_heading level0 row5" >sixties+</th>
#       <td id="T_e9bb0_row5_col0" class="data row5 col0" >5.6</td>
#       <td id="T_e9bb0_row5_col1" class="data row5 col1" >5.6</td>
#       <td id="T_e9bb0_row5_col2" class="data row5 col2" >5.6</td>
#     </tr>
#   </tbody>
# </table>
# Analyzing subset: whisper-base
# <style type="text/css">
# #T_773a2_row0_col0, #T_773a2_row1_col1, #T_773a2_row1_col2, #T_773a2_row2_col0, #T_773a2_row2_col1, #T_773a2_row2_col2, #T_773a2_row3_col0, #T_773a2_row3_col1, #T_773a2_row3_col2, #T_773a2_row4_col0, #T_773a2_row4_col1, #T_773a2_row4_col2 {
#   background-color: white;
#   color: black;
# }
# #T_773a2_row0_col1, #T_773a2_row0_col2, #T_773a2_row1_col0 {
#   background-color: #f5cccc;
#   color: black;
# }
# #T_773a2_row5_col0, #T_773a2_row5_col1, #T_773a2_row5_col2 {
#   background-color: #cce5cc;
#   color: black;
# }
# </style>
# <table id="T_773a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_773a2_level0_col0" class="col_heading level0 col0" >female</th>
#       <th id="T_773a2_level0_col1" class="col_heading level0 col1" >male</th>
#       <th id="T_773a2_level0_col2" class="col_heading level0 col2" >Avg</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_773a2_level0_row0" class="row_heading level0 row0" >teens</th>
#       <td id="T_773a2_row0_col0" class="data row0 col0" >35.8</td>
#       <td id="T_773a2_row0_col1" class="data row0 col1" >35.7</td>
#       <td id="T_773a2_row0_col2" class="data row0 col2" >35.7</td>
#     </tr>
#     <tr>
#       <th id="T_773a2_level0_row1" class="row_heading level0 row1" >twenties</th>
#       <td id="T_773a2_row1_col0" class="data row1 col0" >36.0</td>
#       <td id="T_773a2_row1_col1" class="data row1 col1" >31.3</td>
#       <td id="T_773a2_row1_col2" class="data row1 col2" >33.7</td>
#     </tr>
#     <tr>
#       <th id="T_773a2_level0_row2" class="row_heading level0 row2" >thirties</th>
#       <td id="T_773a2_row2_col0" class="data row2 col0" >34.8</td>
#       <td id="T_773a2_row2_col1" class="data row2 col1" >32.3</td>
#       <td id="T_773a2_row2_col2" class="data row2 col2" >33.6</td>
#     </tr>
#     <tr>
#       <th id="T_773a2_level0_row3" class="row_heading level0 row3" >fourties</th>
#       <td id="T_773a2_row3_col0" class="data row3 col0" >27.5</td>
#       <td id="T_773a2_row3_col1" class="data row3 col1" >32.8</td>
#       <td id="T_773a2_row3_col2" class="data row3 col2" >30.3</td>
#     </tr>
#     <tr>
#       <th id="T_773a2_level0_row4" class="row_heading level0 row4" >fifties</th>
#       <td id="T_773a2_row4_col0" class="data row4 col0" >32.0</td>
#       <td id="T_773a2_row4_col1" class="data row4 col1" >28.2</td>
#       <td id="T_773a2_row4_col2" class="data row4 col2" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_773a2_level0_row5" class="row_heading level0 row5" >sixties+</th>
#       <td id="T_773a2_row5_col0" class="data row5 col0" >24.1</td>
#       <td id="T_773a2_row5_col1" class="data row5 col1" >23.2</td>
#       <td id="T_773a2_row5_col2" class="data row5 col2" >23.5</td>
#     </tr>
#   </tbody>
# </table>
# Analyzing subset: whisper-large-v3
# <style type="text/css">
# #T_c9cdf_row0_col0, #T_c9cdf_row1_col1, #T_c9cdf_row1_col2, #T_c9cdf_row2_col0, #T_c9cdf_row2_col1, #T_c9cdf_row2_col2, #T_c9cdf_row3_col1, #T_c9cdf_row3_col2, #T_c9cdf_row4_col0, #T_c9cdf_row4_col1, #T_c9cdf_row4_col2, #T_c9cdf_row5_col0 {
#   background-color: white;
#   color: black;
# }
# #T_c9cdf_row0_col1, #T_c9cdf_row0_col2, #T_c9cdf_row1_col0 {
#   background-color: #f5cccc;
#   color: black;
# }
# #T_c9cdf_row3_col0, #T_c9cdf_row5_col1, #T_c9cdf_row5_col2 {
#   background-color: #cce5cc;
#   color: black;
# }
# </style>
# <table id="T_c9cdf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9cdf_level0_col0" class="col_heading level0 col0" >female</th>
#       <th id="T_c9cdf_level0_col1" class="col_heading level0 col1" >male</th>
#       <th id="T_c9cdf_level0_col2" class="col_heading level0 col2" >Avg</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9cdf_level0_row0" class="row_heading level0 row0" >teens</th>
#       <td id="T_c9cdf_row0_col0" class="data row0 col0" >3.6</td>
#       <td id="T_c9cdf_row0_col1" class="data row0 col1" >5.3</td>
#       <td id="T_c9cdf_row0_col2" class="data row0 col2" >5.2</td>
#     </tr>
#     <tr>
#       <th id="T_c9cdf_level0_row1" class="row_heading level0 row1" >twenties</th>
#       <td id="T_c9cdf_row1_col0" class="data row1 col0" >5.2</td>
#       <td id="T_c9cdf_row1_col1" class="data row1 col1" >3.9</td>
#       <td id="T_c9cdf_row1_col2" class="data row1 col2" >4.6</td>
#     </tr>
#     <tr>
#       <th id="T_c9cdf_level0_row2" class="row_heading level0 row2" >thirties</th>
#       <td id="T_c9cdf_row2_col0" class="data row2 col0" >4.5</td>
#       <td id="T_c9cdf_row2_col1" class="data row2 col1" >4.5</td>
#       <td id="T_c9cdf_row2_col2" class="data row2 col2" >4.5</td>
#     </tr>
#     <tr>
#       <th id="T_c9cdf_level0_row3" class="row_heading level0 row3" >fourties</th>
#       <td id="T_c9cdf_row3_col0" class="data row3 col0" >2.2</td>
#       <td id="T_c9cdf_row3_col1" class="data row3 col1" >3.8</td>
#       <td id="T_c9cdf_row3_col2" class="data row3 col2" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_c9cdf_level0_row4" class="row_heading level0 row4" >fifties</th>
#       <td id="T_c9cdf_row4_col0" class="data row4 col0" >4.0</td>
#       <td id="T_c9cdf_row4_col1" class="data row4 col1" >3.6</td>
#       <td id="T_c9cdf_row4_col2" class="data row4 col2" >3.8</td>
#     </tr>
#     <tr>
#       <th id="T_c9cdf_level0_row5" class="row_heading level0 row5" >sixties+</th>
#       <td id="T_c9cdf_row5_col0" class="data row5 col0" >3.0</td>
#       <td id="T_c9cdf_row5_col1" class="data row5 col1" >2.1</td>
#       <td id="T_c9cdf_row5_col2" class="data row5 col2" >2.3</td>
#     </tr>
#   </tbody>
# </table>
# Analyzing subset: whisper-large-v3-turbo
# <style type="text/css">
# #T_7b5e6_row0_col0, #T_7b5e6_row0_col1, #T_7b5e6_row0_col2 {
#   background-color: #f5cccc;
#   color: black;
# }
# #T_7b5e6_row1_col0, #T_7b5e6_row1_col1, #T_7b5e6_row1_col2, #T_7b5e6_row2_col0, #T_7b5e6_row2_col1, #T_7b5e6_row2_col2, #T_7b5e6_row3_col0, #T_7b5e6_row3_col1, #T_7b5e6_row3_col2, #T_7b5e6_row4_col0, #T_7b5e6_row4_col1, #T_7b5e6_row4_col2 {
#   background-color: white;
#   color: black;
# }
# #T_7b5e6_row5_col0, #T_7b5e6_row5_col1, #T_7b5e6_row5_col2 {
#   background-color: #cce5cc;
#   color: black;
# }
# </style>
# <table id="T_7b5e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b5e6_level0_col0" class="col_heading level0 col0" >female</th>
#       <th id="T_7b5e6_level0_col1" class="col_heading level0 col1" >male</th>
#       <th id="T_7b5e6_level0_col2" class="col_heading level0 col2" >Avg</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b5e6_level0_row0" class="row_heading level0 row0" >teens</th>
#       <td id="T_7b5e6_row0_col0" class="data row0 col0" >7.2</td>
#       <td id="T_7b5e6_row0_col1" class="data row0 col1" >6.5</td>
#       <td id="T_7b5e6_row0_col2" class="data row0 col2" >6.6</td>
#     </tr>
#     <tr>
#       <th id="T_7b5e6_level0_row1" class="row_heading level0 row1" >twenties</th>
#       <td id="T_7b5e6_row1_col0" class="data row1 col0" >6.1</td>
#       <td id="T_7b5e6_row1_col1" class="data row1 col1" >4.8</td>
#       <td id="T_7b5e6_row1_col2" class="data row1 col2" >5.4</td>
#     </tr>
#     <tr>
#       <th id="T_7b5e6_level0_row2" class="row_heading level0 row2" >thirties</th>
#       <td id="T_7b5e6_row2_col0" class="data row2 col0" >5.7</td>
#       <td id="T_7b5e6_row2_col1" class="data row2 col1" >5.5</td>
#       <td id="T_7b5e6_row2_col2" class="data row2 col2" >5.6</td>
#     </tr>
#     <tr>
#       <th id="T_7b5e6_level0_row3" class="row_heading level0 row3" >fourties</th>
#       <td id="T_7b5e6_row3_col0" class="data row3 col0" >2.6</td>
#       <td id="T_7b5e6_row3_col1" class="data row3 col1" >4.1</td>
#       <td id="T_7b5e6_row3_col2" class="data row3 col2" >3.4</td>
#     </tr>
#     <tr>
#       <th id="T_7b5e6_level0_row4" class="row_heading level0 row4" >fifties</th>
#       <td id="T_7b5e6_row4_col0" class="data row4 col0" >4.1</td>
#       <td id="T_7b5e6_row4_col1" class="data row4 col1" >4.0</td>
#       <td id="T_7b5e6_row4_col2" class="data row4 col2" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_7b5e6_level0_row5" class="row_heading level0 row5" >sixties+</th>
#       <td id="T_7b5e6_row5_col0" class="data row5 col0" >2.5</td>
#       <td id="T_7b5e6_row5_col1" class="data row5 col1" >2.8</td>
#       <td id="T_7b5e6_row5_col2" class="data row5 col2" >2.7</td>
#     </tr>
#   </tbody>
# </table>
# Analyzing subset: whisper-medium
# <style type="text/css">
# #T_4f065_row0_col0, #T_4f065_row1_col1, #T_4f065_row1_col2, #T_4f065_row2_col0, #T_4f065_row2_col1, #T_4f065_row2_col2, #T_4f065_row3_col0, #T_4f065_row3_col1, #T_4f065_row3_col2, #T_4f065_row4_col0, #T_4f065_row4_col1, #T_4f065_row4_col2 {
#   background-color: white;
#   color: black;
# }
# #T_4f065_row0_col1, #T_4f065_row0_col2, #T_4f065_row1_col0 {
#   background-color: #f5cccc;
#   color: black;
# }
# #T_4f065_row5_col0, #T_4f065_row5_col1, #T_4f065_row5_col2 {
#   background-color: #cce5cc;
#   color: black;
# }
# </style>
# <table id="T_4f065">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f065_level0_col0" class="col_heading level0 col0" >female</th>
#       <th id="T_4f065_level0_col1" class="col_heading level0 col1" >male</th>
#       <th id="T_4f065_level0_col2" class="col_heading level0 col2" >Avg</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f065_level0_row0" class="row_heading level0 row0" >teens</th>
#       <td id="T_4f065_row0_col0" class="data row0 col0" >9.4</td>
#       <td id="T_4f065_row0_col1" class="data row0 col1" >10.2</td>
#       <td id="T_4f065_row0_col2" class="data row0 col2" >10.1</td>
#     </tr>
#     <tr>
#       <th id="T_4f065_level0_row1" class="row_heading level0 row1" >twenties</th>
#       <td id="T_4f065_row1_col0" class="data row1 col0" >9.6</td>
#       <td id="T_4f065_row1_col1" class="data row1 col1" >8.1</td>
#       <td id="T_4f065_row1_col2" class="data row1 col2" >8.8</td>
#     </tr>
#     <tr>
#       <th id="T_4f065_level0_row2" class="row_heading level0 row2" >thirties</th>
#       <td id="T_4f065_row2_col0" class="data row2 col0" >8.2</td>
#       <td id="T_4f065_row2_col1" class="data row2 col1" >8.3</td>
#       <td id="T_4f065_row2_col2" class="data row2 col2" >8.3</td>
#     </tr>
#     <tr>
#       <th id="T_4f065_level0_row3" class="row_heading level0 row3" >fourties</th>
#       <td id="T_4f065_row3_col0" class="data row3 col0" >5.4</td>
#       <td id="T_4f065_row3_col1" class="data row3 col1" >7.5</td>
#       <td id="T_4f065_row3_col2" class="data row3 col2" >6.5</td>
#     </tr>
#     <tr>
#       <th id="T_4f065_level0_row4" class="row_heading level0 row4" >fifties</th>
#       <td id="T_4f065_row4_col0" class="data row4 col0" >7.4</td>
#       <td id="T_4f065_row4_col1" class="data row4 col1" >7.0</td>
#       <td id="T_4f065_row4_col2" class="data row4 col2" >7.2</td>
#     </tr>
#     <tr>
#       <th id="T_4f065_level0_row5" class="row_heading level0 row5" >sixties+</th>
#       <td id="T_4f065_row5_col0" class="data row5 col0" >4.7</td>
#       <td id="T_4f065_row5_col1" class="data row5 col1" >4.5</td>
#       <td id="T_4f065_row5_col2" class="data row5 col2" >4.6</td>
#     </tr>
#   </tbody>
# </table>
# Analyzing subset: whisper-small
# <style type="text/css">
# #T_ba12f_row0_col0, #T_ba12f_row0_col1, #T_ba12f_row0_col2 {
#   background-color: #f5cccc;
#   color: black;
# }
# #T_ba12f_row1_col0, #T_ba12f_row1_col1, #T_ba12f_row1_col2, #T_ba12f_row2_col0, #T_ba12f_row2_col1, #T_ba12f_row2_col2, #T_ba12f_row3_col1, #T_ba12f_row3_col2, #T_ba12f_row4_col0, #T_ba12f_row4_col1, #T_ba12f_row4_col2 {
#   background-color: white;
#   color: black;
# }
# #T_ba12f_row3_col0, #T_ba12f_row5_col0, #T_ba12f_row5_col1, #T_ba12f_row5_col2 {
#   background-color: #cce5cc;
#   color: black;
# }
# </style>
# <table id="T_ba12f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba12f_level0_col0" class="col_heading level0 col0" >female</th>
#       <th id="T_ba12f_level0_col1" class="col_heading level0 col1" >male</th>
#       <th id="T_ba12f_level0_col2" class="col_heading level0 col2" >Avg</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba12f_level0_row0" class="row_heading level0 row0" >teens</th>
#       <td id="T_ba12f_row0_col0" class="data row0 col0" >18.8</td>
#       <td id="T_ba12f_row0_col1" class="data row0 col1" >17.9</td>
#       <td id="T_ba12f_row0_col2" class="data row0 col2" >18.0</td>
#     </tr>
#     <tr>
#       <th id="T_ba12f_level0_row1" class="row_heading level0 row1" >twenties</th>
#       <td id="T_ba12f_row1_col0" class="data row1 col0" >17.6</td>
#       <td id="T_ba12f_row1_col1" class="data row1 col1" >15.1</td>
#       <td id="T_ba12f_row1_col2" class="data row1 col2" >16.4</td>
#     </tr>
#     <tr>
#       <th id="T_ba12f_level0_row2" class="row_heading level0 row2" >thirties</th>
#       <td id="T_ba12f_row2_col0" class="data row2 col0" >16.2</td>
#       <td id="T_ba12f_row2_col1" class="data row2 col1" >15.1</td>
#       <td id="T_ba12f_row2_col2" class="data row2 col2" >15.7</td>
#     </tr>
#     <tr>
#       <th id="T_ba12f_level0_row3" class="row_heading level0 row3" >fourties</th>
#       <td id="T_ba12f_row3_col0" class="data row3 col0" >10.3</td>
#       <td id="T_ba12f_row3_col1" class="data row3 col1" >14.2</td>
#       <td id="T_ba12f_row3_col2" class="data row3 col2" >12.3</td>
#     </tr>
#     <tr>
#       <th id="T_ba12f_level0_row4" class="row_heading level0 row4" >fifties</th>
#       <td id="T_ba12f_row4_col0" class="data row4 col0" >14.8</td>
#       <td id="T_ba12f_row4_col1" class="data row4 col1" >12.2</td>
#       <td id="T_ba12f_row4_col2" class="data row4 col2" >13.4</td>
#     </tr>
#     <tr>
#       <th id="T_ba12f_level0_row5" class="row_heading level0 row5" >sixties+</th>
#       <td id="T_ba12f_row5_col0" class="data row5 col0" >10.3</td>
#       <td id="T_ba12f_row5_col1" class="data row5 col1" >9.7</td>
#       <td id="T_ba12f_row5_col2" class="data row5 col2" >9.9</td>
#     </tr>
#   </tbody>
# </table>
# Analyzing subset: whisper-tiny
# <style type="text/css">
# #T_fa05a_row0_col0, #T_fa05a_row0_col2, #T_fa05a_row1_col1, #T_fa05a_row2_col0, #T_fa05a_row2_col1, #T_fa05a_row2_col2, #T_fa05a_row3_col0, #T_fa05a_row3_col1, #T_fa05a_row3_col2, #T_fa05a_row4_col0, #T_fa05a_row4_col1, #T_fa05a_row4_col2 {
#   background-color: white;
#   color: black;
# }
# #T_fa05a_row0_col1, #T_fa05a_row1_col0, #T_fa05a_row1_col2 {
#   background-color: #f5cccc;
#   color: black;
# }
# #T_fa05a_row5_col0, #T_fa05a_row5_col1, #T_fa05a_row5_col2 {
#   background-color: #cce5cc;
#   color: black;
# }
# </style>
# <table id="T_fa05a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa05a_level0_col0" class="col_heading level0 col0" >female</th>
#       <th id="T_fa05a_level0_col1" class="col_heading level0 col1" >male</th>
#       <th id="T_fa05a_level0_col2" class="col_heading level0 col2" >Avg</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa05a_level0_row0" class="row_heading level0 row0" >teens</th>
#       <td id="T_fa05a_row0_col0" class="data row0 col0" >49.3</td>
#       <td id="T_fa05a_row0_col1" class="data row0 col1" >49.6</td>
#       <td id="T_fa05a_row0_col2" class="data row0 col2" >49.6</td>
#     </tr>
#     <tr>
#       <th id="T_fa05a_level0_row1" class="row_heading level0 row1" >twenties</th>
#       <td id="T_fa05a_row1_col0" class="data row1 col0" >55.2</td>
#       <td id="T_fa05a_row1_col1" class="data row1 col1" >47.7</td>
#       <td id="T_fa05a_row1_col2" class="data row1 col2" >51.5</td>
#     </tr>
#     <tr>
#       <th id="T_fa05a_level0_row2" class="row_heading level0 row2" >thirties</th>
#       <td id="T_fa05a_row2_col0" class="data row2 col0" >51.1</td>
#       <td id="T_fa05a_row2_col1" class="data row2 col1" >47.5</td>
#       <td id="T_fa05a_row2_col2" class="data row2 col2" >49.3</td>
#     </tr>
#     <tr>
#       <th id="T_fa05a_level0_row3" class="row_heading level0 row3" >fourties</th>
#       <td id="T_fa05a_row3_col0" class="data row3 col0" >50.2</td>
#       <td id="T_fa05a_row3_col1" class="data row3 col1" >48.6</td>
#       <td id="T_fa05a_row3_col2" class="data row3 col2" >49.4</td>
#     </tr>
#     <tr>
#       <th id="T_fa05a_level0_row4" class="row_heading level0 row4" >fifties</th>
#       <td id="T_fa05a_row4_col0" class="data row4 col0" >54.9</td>
#       <td id="T_fa05a_row4_col1" class="data row4 col1" >47.3</td>
#       <td id="T_fa05a_row4_col2" class="data row4 col2" >51.0</td>
#     </tr>
#     <tr>
#       <th id="T_fa05a_level0_row5" class="row_heading level0 row5" >sixties+</th>
#       <td id="T_fa05a_row5_col0" class="data row5 col0" >38.5</td>
#       <td id="T_fa05a_row5_col1" class="data row5 col1" >39.2</td>
#       <td id="T_fa05a_row5_col2" class="data row5 col2" >39.0</td>
#     </tr>
#   </tbody>
# </table>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
